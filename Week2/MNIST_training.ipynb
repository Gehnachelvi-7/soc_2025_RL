# %%
# !pip install torch torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/gehna/.local/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: torchvision in /home/gehna/.local/lib/python3.10/site-packages (0.22.1)
# Requirement already satisfied: triton==3.3.1 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (3.3.1)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: jinja2 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (2.26.2)
# Requirement already satisfied: filelock in /home/gehna/.local/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /home/gehna/.local/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: sympy>=1.13.3 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: fsspec in /home/gehna/.local/lib/python3.10/site-packages (from torch) (2025.5.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/gehna/.local/lib/python3.10/site-packages (from torch) (12.6.85)
# Requirement already satisfied: setuptools>=40.8.0 in /home/gehna/.local/lib/python3.10/site-packages (from triton==3.3.1->torch) (80.9.0)
# Requirement already satisfied: numpy in /home/gehna/.local/lib/python3.10/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/gehna/.local/lib/python3.10/site-packages (from torchvision) (11.2.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/gehna/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gehna/.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)

# %%
# !pip install matplotlib scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/gehna/.local/lib/python3.10/site-packages (3.7.4)
# Requirement already satisfied: scikit-learn in /home/gehna/.local/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: packaging>=20.0 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: cycler>=0.10 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy<2,>=1.20 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/gehna/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.8.0 in /home/gehna/.local/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/gehna/.local/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: six>=1.5 in /home/gehna/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install numpy==1.26.4 matplotlib==3.7.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy==1.26.4 in /home/gehna/.local/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: matplotlib==3.7.4 in /home/gehna/.local/lib/python3.10/site-packages (3.7.4)
# Requirement already satisfied: packaging>=20.0 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (25.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (11.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (2.9.0.post0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (1.4.8)
# Requirement already satisfied: fonttools>=4.22.0 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (4.58.4)
# Requirement already satisfied: cycler>=0.10 in /home/gehna/.local/lib/python3.10/site-packages (from matplotlib==3.7.4) (0.12.1)
# Requirement already satisfied: six>=1.5 in /home/gehna/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib==3.7.4) (1.17.0)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplaytrain_loader
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transform)

loader_train = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 9.91M/9.91M [00:05<00:00, 1.87MB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 91.0kB/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 1.65M/1.65M [00:09<00:00, 168kB/s]
# 100%|███████████████████████████████████████████████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 112kB/s]

# %%
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 10)
        )

    def forward(self, x):
        return self.fc(x)

# CNN Model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(16, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32*7*7, 128),
            nn.ReLU(),
            nn.Linear(128, 10)
        )

    def forward(self, x):
        x = self.conv(x)
        x = self.fc(x)
        return x

# Training
def train_model(model, epochs=5):
    model.to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters())

    train_losses, test_accuracies = [], []

    for epoch in range(epochs):
        model.train()
        running_loss = 0
        for images, labels in loader_train:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            output = model(images)
            loss = criterion(output, labels)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
        train_losses.append(running_loss / len(loader_train))

        # Evaluate
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for images, labels in test_loader:
                images, labels = images.to(device), labels.to(device)
                output = model(images)
                _, predicted = torch.max(output.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        acc = 100 * correct / total
        test_accuracies.append(acc)
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {train_losses[-1]:.4f}, Accuracy: {acc:.2f}%")

    return train_losses, test_accuracies

# Plotting
def plot_metrics(train_losses, test_accuracies):
    epochs = range(1, len(train_losses) + 1)
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs, train_losses, label='Train Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss vs Epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs, test_accuracies, label='Test Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Accuracy vs Epochs')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Confusion matrix
def diaplay_confusion(model):
    model.eval()
    all_preds, all_labels = [], []
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.numpy())

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(10))
    disp.plot(cmap='viridis')
    plt.title("Confusion Matrix")
    plt.show()

# Run and compare both models
print("\n--- Training Simple Feedforward NN ---")
nn_model = SimpleNN()
nn_losses, nn_accuracies = train_model(nn_model)

print("\n--- Training CNN Model ---")
cnn_model = CNN()
cnn_losses, cnn_accuracies = train_model(cnn_model)

# Plot
plot_metrics(nn_losses, nn_accuracies)
plot_metrics(cnn_losses, cnn_accuracies)

# Confusion matrix for CNN
diaplay_confusion(cnn_model)

# Save model
torch.save(cnn_model.state_dict(), 'cnn_mnist_model.pth')
print("CNN model saved as cnn_mnist_model.pth")
# Out:
# --- Training Simple Feedforward NN ---
# Epoch [1/5], Loss: 0.2730, Accuracy: 95.89%
# Epoch [2/5], Loss: 0.1165, Accuracy: 97.18%
# Epoch [3/5], Loss: 0.0815, Accuracy: 97.12%
# Epoch [4/5], Loss: 0.0641, Accuracy: 97.10%
# Epoch [5/5], Loss: 0.0500, Accuracy: 96.89%
#
# --- Training CNN Model ---
# Epoch [1/5], Loss: 0.1647, Accuracy: 98.42%
# Epoch [2/5], Loss: 0.0490, Accuracy: 98.13%
# Epoch [3/5], Loss: 0.0341, Accuracy: 99.01%
# Epoch [4/5], Loss: 0.0243, Accuracy: 99.06%
# Epoch [5/5], Loss: 0.0191, Accuracy: 99.01%
# CNN model saved as cnn_mnist_model.pth
